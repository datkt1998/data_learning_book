# %%
import os

# %%
os.path.(os.getcwd())
# Out:
# '/Volumes/GoogleDrive-106231888590528523181/My Drive/GitCode/My_learning/11. BigData/5. Polar'

# %%
data = r'/Volumes/KTD1TB_1/DataRaw/Telco Info/telco info/Subcriber Telco Info/TTTB Viettel/2021_05/part_2.csv'

# %%
import pandas as pd

# %%
pd.read_csv(data, nrows=10, sep = "|")
# Out:
#         MSISDN LOAI_KHACH_HANG DOITUONG_SD           HOVATEN_TB NGAYSINH_TB  \
# 0  84368303746              CN        CN01          Dam gia Pho  1982-10-17
# 1  84368360418              CN        CN01     Nguyễn Thị Ty Ty  1970-03-18
# 2  84368408589              CN        CN03  HOÀNG THỊ THU HƯƠNG  1980-04-11
# 3  84368463948              CN        CN01      Nguyễn Thị Phin  1964-09-02
# 4  84368516500              CN        CN01  Diệp Thị Kim Nguyệt  1951-05-01
# 5  84368568817              CN        CN01     Đoàn Thị Tính  1972-02-09
# 6  84368617558              CN        CN01       Tiền Thanh Tân  1983-12-21
# 7  84368670652              CN        CN01         Hồ Quốc Tuấn  1993-08-15
# 8  84368731678              CN        CN01        Trần Văn Thái  1993-01-01
# 9  84368788345              CN        CN01   Phạm Thị Minh Nhân  2000-05-02
#
#   QUOCTICH_TB LOAIGIAYTO_TB  SOGIAYTO_TB  NGAYCAP_TB          NOICAP_TB  ...  \
# ...

# %%
pd.read_csv(r'/Volumes/KTD1TB_1/DataRaw/Telco Info/telco info/Subcriber Telco Info/TTTB Viettel/2019/exportDataViettel.csv', nrows=10, sep = ",")
# Out:
#          INFO1 LOAI_THUE_BAO   MA_GOI_CUOC  ACTIVE_DATE            CITY  \
# 0  11192359457      PRE_PAID        LTEASY     20120416     Hồ Chí Minh
# 1  11193175472      PRE_PAID     TOM690_12     20150907      Quảng Bình
# 2  10995705277      PRE_PAID         HISCL     20110707     ca hưng yên
# 3  10936961661      PRE_PAID        S1081T     20110614    Ca Thanh Hóa
# 4  11063480931      PRE_PAID         TOM11     20070716      Bình Thuận
# 5  11161437402      PRE_PAID  TOM_BUNDLE15     20100621      Bình Dương
# 6  11084381502      PRE_PAID      SUMO_LOW     20070511       Vĩnh Phúc
# 7  11165860128      PRE_PAID         TOM11     20160114  TP.Hồ Chí Minh
# 8  11183578095      PRE_PAID         TOM11     20111027        Trà Vinh
# 9   1007447002      PRE_PAID        TOM690     20060703        Đăk Nông
#
#    BIRTH_DATE                                       ADDRESS             NAME  \
# 0    19620612    vân hàn Xã Trung Lập Thượng H.Củ Chi TPHCM     Thân Thị Hời
# ...

# %%
db = r'/Volumes/KTD1TB_1/DataCleaned/DTT_Oracle/telco_info/telco_info_score.db'

# %%
import pandas as pd
from sys import path
path.append(r'/Volumes/GoogleDrive-106231888590528523181/My Drive/GitCode/My_modules')
from datpy.helptool.connection import DatabaseSQL, Database
from datpy.eda.dataframe import display
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 4
#       2 from sys import path
#       3 path.append(r'/Volumes/GoogleDrive-106231888590528523181/My Drive/GitCode/My_modules')
# ----> 4 from datpy.helptool.connection import DatabaseSQL, Database
#       5 from datpy.eda.dataframe import display
#
# File /Volumes/GoogleDrive-106231888590528523181/My Drive/GitCode/My_modules/datpy/helptool/connection.py:4
#       2 import io
#       3 from google.auth.transport.requests import Request
# ----> 4 from googleapiclient.http import MediaFileUpload, MediaIoBaseDownload
#       5 from googleapiclient.discovery import build
#       6 from google_auth_oauthlib.flow import Flow, InstalledAppFlow
#
# ModuleNotFoundError: No module named 'googleapiclient'

# %%
# !pip install googleapiclient munch
# Out:
# ERROR: Could not find a version that satisfies the requirement googleapiclient (from versions: none)
# ERROR: No matching distribution found for googleapiclient
